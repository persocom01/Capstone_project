# %%
import pandas as pd
pd.options.display.max_columns=110
pd.options.display.max_rows=300
import numpy as np
import pleiades as ple

# %%
import_path = r'..\data\#michellewilliams_classify.csv'
data = pd.read_csv(import_path, low_memory=False)

import_path = r'..\data\#michellewilliams_classify2.csv'
data2 = pd.read_csv(import_path, low_memory=False)

# %%
nabe = ple.Nabe()

# %%
data.shape
# Out:
# (13482, 5)

# %%
nabe.get_nulls(data)
# Out:
# {'retweeted_status.id_str': 3032,
#  'retweeted_status.full_text': 12784,
#  'conservative': 4990}

# %%
data['conservative'] = data2['conservative']

# %%
n = 12945

# %%
data.loc[n]
# Out:
# id_str                                                      1214023293239484417
# full_text                     RT @AnnDystopianFan: I love Michelle Williams ...
# retweeted_status.id_str                                             1.21402e+18
# retweeted_status.full_text                                                  NaN
# conservative                                                                NaN
# Name: 12945, dtype: object

# %%
t = data['full_text'][n]
t
# Out:
# 'RT @AnnDystopianFan: I love Michelle Williams so much. Not only is she talented and beautiful, but she’s a champion for women. “Please vote…'

# %%
data['conservative'] = [0 if x == t else y for x, y in zip(data['full_text'], data['conservative'])]

# %%
export_path = r'..\data\#michellewilliams_classify.csv'
data.to_csv(export_path, index=False)

# %%
nabe = ple.Nabe()

# %%
df = nabe.drop_null_cols(data)

# %%
df.shape
# Out:
# (13629, 117)

# %%
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Mon Jan 13 02:34:54 +0000 2020  1216549150361300992  1216549150361300992
# 1  Mon Jan 13 02:34:52 +0000 2020  1216549141825744897  1216549141825744897
# 2  Mon Jan 13 02:34:22 +0000 2020  1216549017884266496  1216549017884266496
# 3  Mon Jan 13 02:34:08 +0000 2020  1216548956131536896  1216548956131536896
# 4  Mon Jan 13 02:33:58 +0000 2020  1216548914905538560  1216548914905538560
#
#                                            full_text  truncated  \
# 0  RT @CriticsChoice: #Michellewilliams wins the ...      False
# 1  RT @CriticsChoice: #Michellewilliams wins the ...      False
# 2  RT @CriticsChoice: #Michellewilliams wins the ...      False
# 3  RT @CriticsChoice: #Michellewilliams wins the ...      False
# 4  RT @CriticsChoice: #Michellewilliams wins the ...      False
#
#                                               source  is_quote_status  \
# 0  <a href="http://twitter.com/download/iphone" r...            False
# 1  <a href="http://twitter.com/download/iphone" r...            False
# 2  <a href="http://twitter.com/download/iphone" r...            False
# 3  <a href="http://twitter.com/download/iphone" r...            False
# 4  <a href="http://twitter.com/download/android" ...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang  \
# 0            158               0      False      False   en
# 1            158               0      False      False   en
# 2            158               0      False      False   en
# 3            158               0      False      False   en
# 4            158               0      False      False   en
#
#                                    entities.hashtags entities.symbols  \
# 0  [{'text': 'Michellewilliams', 'indices': [19, ...               []
# 1  [{'text': 'Michellewilliams', 'indices': [19, ...               []
# 2  [{'text': 'Michellewilliams', 'indices': [19, ...               []
# 3  [{'text': 'Michellewilliams', 'indices': [19, ...               []
# 4  [{'text': 'Michellewilliams', 'indices': [19, ...               []
#
#                               entities.user_mentions entities.urls  \
# 0  [{'screen_name': 'CriticsChoice', 'name': "Cri...            []
# 1  [{'screen_name': 'CriticsChoice', 'name': "Cri...            []
# 2  [{'screen_name': 'CriticsChoice', 'name': "Cri...            []
# 3  [{'screen_name': 'CriticsChoice', 'name': "Cri...            []
# 4  [{'screen_name': 'CriticsChoice', 'name': "Cri...            []
#
#   metadata.iso_language_code metadata.result_type             user.id  \
# 0                         en               recent           460807336
# 1                         en               recent           167441120
# 2                         en               recent           396326986
# 3                         en               recent  779733539826860032
# 4                         en               recent  907454761766494208
#
#           user.id_str          user.name user.screen_name     user.location  \
# 0           460807336  Effortlessly Chic  effortlessheart  Once And Forever
# 1           167441120        Keinosuke O            HIP_K  Chiba Pref,Japan
# 2           396326986        Alex McGill       Aleex_Lara   Yucatán, México
# 3  779733539826860032            allison   goldenhrgrande       multifandom
# 4  907454761766494208  Bicara Box Office  bicaraboxoffice         Indonesia
#
#                                     user.description  \
# 0  Fashion,Music,Movies,Taylor Swift, Lana Del Re...
# 1  I love the motion picture,the music,my friends...
# 2                           TKD // FCA, UADY // MUFC
# 3                                                NaN
# 4  Also on https://t.co/m5KBUKLos2  IG https://t....
#
#                       user.entities.description.urls  user.protected  \
# 0                                                 []           False
# 1                                                 []           False
# 2                                                 []           False
# 3                                                 []           False
# 4  [{'url': 'https://t.co/m5KBUKLos2', 'expanded_...           False
#
#    user.followers_count  user.friends_count  user.listed_count  \
# 0                  1071                 613                 71
# 1                  1350                3186                 27
# 2                   337                 321                 11
# 3                   921                3940                 10
# 4                 45748                 412                 93
#
#                   user.created_at  user.favourites_count  user.geo_enabled  \
# 0  Wed Jan 11 04:21:31 +0000 2012                   5365              True
# 1  Fri Jul 16 16:07:34 +0000 2010                 127881              True
# 2  Sun Oct 23 03:22:20 +0000 2011                  75580              True
# 3  Sat Sep 24 17:25:37 +0000 2016                  48393              True
# 4  Tue Sep 12 04:04:09 +0000 2017                   2041              True
#
#    user.verified  user.statuses_count  user.contributors_enabled  \
# 0          False                92055                      False
# 1          False                47224                      False
# 2          False                46919                      False
# 3          False                14595                      False
# 4          False                30295                      False
#
#    user.is_translator  user.is_translation_enabled  \
# 0               False                        False
# 1               False                        False
# 2               False                        False
# 3               False                        False
# 4               False                        False
#
#   user.profile_background_color  \
# 0                        C0DEED
# 1                        C1EBC9
# 2                        ACDED6
# 3                        000000
# 4                        F5F8FA
#
#                    user.profile_background_image_url  \
# 0   http://abs.twimg.com/images/themes/theme1/bg.png
# 1   http://abs.twimg.com/images/themes/theme1/bg.png
# 2  http://abs.twimg.com/images/themes/theme18/bg.gif
# 3   http://abs.twimg.com/images/themes/theme1/bg.png
# 4                                                NaN
#
#              user.profile_background_image_url_https  \
# 0  https://abs.twimg.com/images/themes/theme1/bg.png
# 1  https://abs.twimg.com/images/themes/theme1/bg.png
# 2  https://abs.twimg.com/images/themes/theme18/bg...
# 3  https://abs.twimg.com/images/themes/theme1/bg.png
# 4                                                NaN
#
#    user.profile_background_tile  \
# 0                         False
# 1                          True
# 2                          True
# 3                         False
# 4                         False
#
#                               user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/8827898864...
# 1  http://pbs.twimg.com/profile_images/1209955978...
# 2  http://pbs.twimg.com/profile_images/1040278339...
# 3  http://pbs.twimg.com/profile_images/1170097205...
# 4  http://pbs.twimg.com/profile_images/1113030868...
#
#                         user.profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/882789886...
# 1  https://pbs.twimg.com/profile_images/120995597...
# 2  https://pbs.twimg.com/profile_images/104027833...
# 3  https://pbs.twimg.com/profile_images/117009720...
# 4  https://pbs.twimg.com/profile_images/111303086...
#
#                              user.profile_banner_url user.profile_link_color  \
# 0  https://pbs.twimg.com/profile_banners/46080733...                  1DA1F2
# 1  https://pbs.twimg.com/profile_banners/16744112...                  0018B3
# 2  https://pbs.twimg.com/profile_banners/39632698...                  1B95E0
# 3  https://pbs.twimg.com/profile_banners/77973353...                  ECC5C0
# 4  https://pbs.twimg.com/profile_banners/90745476...                  1DA1F2
#
#   user.profile_sidebar_border_color user.profile_sidebar_fill_color  \
# 0                            C0DEED                          DDEEF6
# 1                            C1EBD7                          E4F5DC
# 2                            FFFFFF                          DDEEF6
# 3                            000000                          000000
# 4                            C0DEED                          DDEEF6
#
#   user.profile_text_color  user.profile_use_background_image  \
# 0                  333333                               True
# 1                  333333                               True
# 2                  333333                               True
# 3                  000000                              False
# 4                  333333                               True
#
#    user.has_extended_profile  user.default_profile  \
# 0                      False                  True
# 1                      False                 False
# 2                      False                 False
# 3                       True                 False
# 4                      False                  True
#
#    user.default_profile_image  user.following  user.follow_request_sent  \
# 0                       False           False                     False
# 1                       False           False                     False
# 2                       False           False                     False
# 3                       False           False                     False
# 4                       False           False                     False
#
#    user.notifications  ...            retweeted_status.entities.user_mentions  \
# 0               False  ...  [{'screen_name': 'FosseVerdonFX', 'name': 'Fos...
# 1               False  ...  [{'screen_name': 'FosseVerdonFX', 'name': 'Fos...
# 2               False  ...  [{'screen_name': 'FosseVerdonFX', 'name': 'Fos...
# 3               False  ...  [{'screen_name': 'FosseVerdonFX', 'name': 'Fos...
# 4               False  ...  [{'screen_name': 'FosseVerdonFX', 'name': 'Fos...
#
#   retweeted_status.entities.urls  retweeted_status.metadata.iso_language_code  \
# 0                             []                                           en
# 1                             []                                           en
# 2                             []                                           en
# 3                             []                                           en
# 4                             []                                           en
#
#    retweeted_status.metadata.result_type  \
# 0                                 recent
# 1                                 recent
# 2                                 recent
# 3                                 recent
# 4                                 recent
#
#                              retweeted_status.source retweeted_status.user.id  \
# 0  <a href="http://twitter.com/download/iphone" r...               83266010.0
# 1  <a href="http://twitter.com/download/iphone" r...               83266010.0
# 2  <a href="http://twitter.com/download/iphone" r...               83266010.0
# 3  <a href="http://twitter.com/download/iphone" r...               83266010.0
# 4  <a href="http://twitter.com/download/iphone" r...               83266010.0
#
#   retweeted_status.user.id_str retweeted_status.user.name  \
# 0                   83266010.0            Critics' Choice
# 1                   83266010.0            Critics' Choice
# 2                   83266010.0            Critics' Choice
# 3                   83266010.0            Critics' Choice
# 4                   83266010.0            Critics' Choice
#
#   retweeted_status.user.screen_name retweeted_status.user.location  \
# 0                     CriticsChoice        Los Angeles, California
# 1                     CriticsChoice        Los Angeles, California
# 2                     CriticsChoice        Los Angeles, California
# 3                     CriticsChoice        Los Angeles, California
# 4                     CriticsChoice        Los Angeles, California
#
#                    retweeted_status.user.description  \
# 0  Official Twitter of the Critics' Choice Awards...
# 1  Official Twitter of the Critics' Choice Awards...
# 2  Official Twitter of the Critics' Choice Awards...
# 3  Official Twitter of the Critics' Choice Awards...
# 4  Official Twitter of the Critics' Choice Awards...
#
#   retweeted_status.user.url  \
# 0   https://t.co/e6MBDpLxdh
# 1   https://t.co/e6MBDpLxdh
# 2   https://t.co/e6MBDpLxdh
# 3   https://t.co/e6MBDpLxdh
# 4   https://t.co/e6MBDpLxdh
#
#              retweeted_status.user.entities.url.urls  \
# 0  [{'url': 'https://t.co/e6MBDpLxdh', 'expanded_...
# 1  [{'url': 'https://t.co/e6MBDpLxdh', 'expanded_...
# 2  [{'url': 'https://t.co/e6MBDpLxdh', 'expanded_...
# 3  [{'url': 'https://t.co/e6MBDpLxdh', 'expanded_...
# 4  [{'url': 'https://t.co/e6MBDpLxdh', 'expanded_...
#
#    retweeted_status.user.entities.description.urls  \
# 0                                               []
# 1                                               []
# 2                                               []
# 3                                               []
# 4                                               []
#
#   retweeted_status.user.protected retweeted_status.user.followers_count  \
# 0                           False                               78275.0
# 1                           False                               78275.0
# 2                           False                               78275.0
# 3                           False                               78275.0
# 4                           False                               78275.0
#
#   retweeted_status.user.friends_count retweeted_status.user.listed_count  \
# 0                              1615.0                              658.0
# 1                              1615.0                              658.0
# 2                              1615.0                              658.0
# 3                              1615.0                              658.0
# 4                              1615.0                              658.0
#
#   retweeted_status.user.created_at retweeted_status.user.favourites_count  \
# 0   Sun Oct 18 01:27:27 +0000 2009                                 2807.0
# 1   Sun Oct 18 01:27:27 +0000 2009                                 2807.0
# 2   Sun Oct 18 01:27:27 +0000 2009                                 2807.0
# 3   Sun Oct 18 01:27:27 +0000 2009                                 2807.0
# 4   Sun Oct 18 01:27:27 +0000 2009                                 2807.0
#
#   retweeted_status.user.geo_enabled retweeted_status.user.verified  \
# 0                              True                           True
# 1                              True                           True
# 2                              True                           True
# 3                              True                           True
# 4                              True                           True
#
#    retweeted_status.user.statuses_count  \
# 0                                8099.0
# 1                                8099.0
# 2                                8099.0
# 3                                8099.0
# 4                                8099.0
#
#    retweeted_status.user.contributors_enabled  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#    retweeted_status.user.is_translator  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#   retweeted_status.user.is_translation_enabled  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    retweeted_status.user.profile_background_color  \
# 0                                          000000
# 1                                          000000
# 2                                          000000
# 3                                          000000
# 4                                          000000
#
#   retweeted_status.user.profile_background_image_url  \
# 0  http://abs.twimg.com/images/themes/theme14/bg.gif
# 1  http://abs.twimg.com/images/themes/theme14/bg.gif
# 2  http://abs.twimg.com/images/themes/theme14/bg.gif
# 3  http://abs.twimg.com/images/themes/theme14/bg.gif
# 4  http://abs.twimg.com/images/themes/theme14/bg.gif
#
#   retweeted_status.user.profile_background_image_url_https  \
# 0  https://abs.twimg.com/images/themes/theme14/bg...
# 1  https://abs.twimg.com/images/themes/theme14/bg...
# 2  https://abs.twimg.com/images/themes/theme14/bg...
# 3  https://abs.twimg.com/images/themes/theme14/bg...
# 4  https://abs.twimg.com/images/themes/theme14/bg...
#
#    retweeted_status.user.profile_background_tile  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#              retweeted_status.user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/1039679149...
# 1  http://pbs.twimg.com/profile_images/1039679149...
# 2  http://pbs.twimg.com/profile_images/1039679149...
# 3  http://pbs.twimg.com/profile_images/1039679149...
# 4  http://pbs.twimg.com/profile_images/1039679149...
#
#        retweeted_status.user.profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/103967914...
# 1  https://pbs.twimg.com/profile_images/103967914...
# 2  https://pbs.twimg.com/profile_images/103967914...
# 3  https://pbs.twimg.com/profile_images/103967914...
# 4  https://pbs.twimg.com/profile_images/103967914...
#
#             retweeted_status.user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/83266010...
# 1  https://pbs.twimg.com/profile_banners/83266010...
# 2  https://pbs.twimg.com/profile_banners/83266010...
# 3  https://pbs.twimg.com/profile_banners/83266010...
# 4  https://pbs.twimg.com/profile_banners/83266010...
#
#   retweeted_status.user.profile_link_color  \
# 0                                   3B94D9
# 1                                   3B94D9
# 2                                   3B94D9
# 3                                   3B94D9
# 4                                   3B94D9
#
#   retweeted_status.user.profile_sidebar_border_color  \
# 0                                             000000
# 1                                             000000
# 2                                             000000
# 3                                             000000
# 4                                             000000
#
#   retweeted_status.user.profile_sidebar_fill_color  \
# 0                                           000000
# 1                                           000000
# 2                                           000000
# 3                                           000000
# 4                                           000000
#
#   retweeted_status.user.profile_text_color  \
# 0                                   000000
# 1                                   000000
# 2                                   000000
# 3                                   000000
# 4                                   000000
#
#   retweeted_status.user.profile_use_background_image  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   retweeted_status.user.has_extended_profile  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#   retweeted_status.user.default_profile  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#   retweeted_status.user.default_profile_image retweeted_status.user.following  \
# 0                                       False                           False
# 1                                       False                           False
# 2                                       False                           False
# 3                                       False                           False
# 4                                       False                           False
#
#   retweeted_status.user.follow_request_sent  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   retweeted_status.user.notifications retweeted_status.user.translator_type  \
# 0                               False                                  none
# 1                               False                                  none
# 2                               False                                  none
# 3                               False                                  none
# 4                               False                                  none
#
#   retweeted_status.is_quote_status retweeted_status.retweet_count  \
# 0                            False                          158.0
# 1                            False                          158.0
# 2                            False                          158.0
# 3                            False                          158.0
# 4                            False                          158.0
#
#   retweeted_status.favorite_count retweeted_status.favorited  \
# 0                           393.0                      False
# 1                           393.0                      False
# 2                           393.0                      False
# 3                           393.0                      False
# 4                           393.0                      False
#
#   retweeted_status.retweeted retweeted_status.possibly_sensitive  \
# 0                      False                               False
# 1                      False                               False
# 2                      False                               False
# 3                      False                               False
# 4                      False                               False
#
#   retweeted_status.lang quoted_status_id  quoted_status_id_str  \
# 0                    en              NaN                   NaN
# 1                    en              NaN                   NaN
# 2                    en              NaN                   NaN
# 3                    en              NaN                   NaN
# 4                    en              NaN                   NaN
#
#    retweeted_status.text
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 117 columns]

# %%
df = data[['id_str', 'full_text', 'retweeted_status.id_str', 'retweeted_status.full_text']]

# %%
df['full_text'][0]
# Out:
# 'RT @CriticsChoice: #Michellewilliams wins the #criticschoice Award for Best Actress In A Limited Series Or Movie Made For Television for he…'

# %%
df['full_text'][0]

# %%
df.shape
# Out:
# (13482, 4)

# %%
df = df[df['full_text'] != 'RT @CriticsChoice: #Michellewilliams wins the #criticschoice Award for Best Actress In A Limited Series Or Movie Made For Television for he…']

# %%
df.shape
# Out:
# (13482, 4)

# %%
df.loc[1008]
# Out:
# id_str                                                      1215470667661004800
# full_text                     RT @V_actually: Hollywood's full of sexual dev...
# retweeted_status.id_str                                             1.21529e+18
# retweeted_status.full_text    Hollywood's full of sexual deviants &amp; pedo...
# Name: 1008, dtype: object

# %%
df['full_text'][1008]
# Out:
# "RT @V_actually: Hollywood's full of sexual deviants &amp; pedophiles that have sold their souls for fame.\n\nIt’s amazing the amount of brainwash…"

# %%
df['conservative'] = df['full_text'].map({'RT @V_actually: Hollywood\'s full of sexual deviants &amp; pedophiles that have sold their souls for fame.\n\nIt’s amazing the amount of brainwash…': 1})

# %%
df['conservative'].count()
# Out:
# 506

# %%
export_path = r'..\data\#michellewilliams_classify3.csv'
df.to_csv(export_path, index=False)

# %%
import_path = r'..\data\#michellewilliams_classify3.csv'
data2 = pd.read_csv(import_path, low_memory=False)

# %%
data2.loc[1205]
# Out:
# id_str                                                      1215316789548199936
# full_text                     RT @americansunited: S/O to #MichelleWilliams ...
# retweeted_status.id_str                                             1.21468e+18
# retweeted_status.full_text                                                  NaN
# conservative                                                                NaN
# Name: 1205, dtype: object

# %%
data2['id_str'][232]
# Out:
# 1216078555152617472

# %%
import_path = r'..\data\#michellewilliams_classify5.csv'
data3 = pd.read_csv(import_path, low_memory=False)

# %%
data3['id_str'][232]
# Out:
# 1.22e+18

# %%
data3.columns
# Out:
# Index(['id_str', 'full_text', 'retweeted_status.id_str',
#        'retweeted_status.full_text', 'conservative'],
#       dtype='object')

# %%
data2['conservative'] = data3['conservative']

# %%
data2['full_text'][101]
# Out:
# "RT @RockofLifeNI: At tonight's #goldenglobes2020 pregnant actress #MichelleWilliams said she wouldn't have won if she hadn't aborted her ot…"

# %%
data2['conservative'] = [1 if x == "RT @RockofLifeNI: At tonight's #goldenglobes2020 pregnant actress #MichelleWilliams said she wouldn't have won if she hadn't aborted her ot…" else y for x, y in zip(data2['full_text'], data2['conservative'])]

# %%
export_path = r'..\data\#michellewilliams_classify7.csv'
data2.to_csv(export_path, index=False)
